# %% [markdown]
# <a href="https://colab.research.google.com/github/hhsharma5/notebookTrials/blob/main/Mathplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

gas = pd.read_csv('gas_prices.csv')

#

plt.figure(figsize=(8, 5))

plt.title('Gas prices over time (in USD)')

plt.plot(gas.Year, gas.USA, 'b.-', 'USA')
plt.plot(gas.Year, gas.USA, 'b.-', 'USA')
